# %% [markdown]
# # Everyone Can Learn Python Scholarship

# %% [markdown]
# ## 📖 Background
# The first "Everyone Can Learn Python" Scholarship from DataCamp is now open for entries.
#
# The challenges below test the Python and SQL skills you gained from Introduction to Python and Introduction to SQL and pair them with your existing problem-solving and creative thinking.
#
# The scholarship is open to people who have completed or are completing their secondary education and are preparing to pursue a degree in computer science or data science. Students preparing for graduate-level computer science or data science degrees are also welcome to apply.

# %% [markdown]
# ## 💡 Learn more
#
# The following DataCamp courses can help review the skills needed for this challenge:
#
# * [Introduction to Python](https://www.datacamp.com/courses/introduction-to-python)
# * [Introduction to SQL](https://www.datacamp.com/courses/introduction-to-sql)

# %% [markdown]
# ## ℹ️ Introduction to Data Science Notebooks
#
# You can skip this section if you are already familiar with data science notebooks.
#
# ### Data science notebooks
# A _data science notebook_ is a document containing text cells (what you're reading now) and code cells. What is unique with a notebook is that it's **interactive**: You can change or add code cells and then **run** a cell by selecting it and then clicking the **Run** button to the right ( <strong>▶</strong>, or Run All on top) or hitting `control + enter`.
#
# The result will be displayed directly in the notebook.
#
# Try running the Python cell below:

# %%
# Run this cell to see the result (click on Run on the right, or control+enter)
100 * 1.75 * 20
# Out:
# 3500.0

# %% [markdown]
# Modify any of the numbers and rerun the cell.
#
# You can add a Markdown, Python, or SQL cell by clicking on the **Add Markdown**, **Add Code**, and **Add SQL** buttons that appear as you move the mouse pointer near the bottom of any cell.
#
# Here at DataCamp, we call our interactive notebook **Workspace**. You can find out more about Workspace [here](https://workspace-docs.datacamp.com/).

# %% [markdown]
# ## 1️⃣ Python 🐍 - CO2 Emissions
#
# Now let's now move on to the competition and challenge.
#
# ## 📖 Background
# You volunteer for a public policy advocacy organization in Canada, and your colleague asked you to help her draft recommendations for guidelines on CO2 emissions rules.
#
# After researching emissions data for a wide range of Canadian vehicles, she would like you to investigate which vehicles produce lower emissions.

# %% [markdown]
# ## 💾 The data I
#
# ### You have access to seven years of CO2 emissions data for Canadian vehicles ([source](https://open.canada.ca/data/en/dataset/98f1a129-f628-4ce4-b24d-6f16bf24dd64#wb-auto-6)):
#
# - "Make" - The company that manufactures the vehicle.
# - "Model" - The vehicle's model.
# - "Vehicle Class" - Vehicle class by utility, capacity, and weight.
# - "Engine Size(L)" - The engine's displacement in liters.
# - "Cylinders" - The number of cylinders.
# - "Transmission" - The transmission type: A = Automatic, AM = Automatic Manual, AS = Automatic with select shift, AV = Continuously variable, M = Manual, 3 - 10 = the number of gears.
# - "Fuel Type" - The fuel type: X = Regular gasoline, Z = Premium gasoline, D = Diesel, E = Ethanol (E85), N = natural gas.
# - "Fuel Consumption Comb (L/100 km)" - Combined city/highway (55%/45%) fuel consumption in liters per 100 km (L/100 km).
# - "CO2 Emissions(g/km)" - The tailpipe carbon dioxide emissions in grams per kilometer for combined city and highway driving.
#
# The data comes from the Government of Canada's open data [website](https://open.canada.ca/en).

# %%
# Import the pandas and numpy packages
import pandas as pd
import numpy as np

# Load the data
cars = pd.read_csv('data/co2_emissions_canada.csv')

# create numpy arrays
cars_makes = cars['Make'].to_numpy()
cars_models = cars['Model'].to_numpy()
cars_classes = cars['Vehicle Class'].to_numpy()
cars_engine_sizes = cars['Engine Size(L)'].to_numpy()
cars_cylinders = cars['Cylinders'].to_numpy()
cars_transmissions = cars['Transmission'].to_numpy()
cars_fuel_types = cars['Fuel Type'].to_numpy()
cars_fuel_consumption = cars['Fuel Consumption Comb (L/100 km)'].to_numpy()
cars_co2_emissions = cars['CO2 Emissions(g/km)'].to_numpy()

# Preview the dataframe
cars
# Out:
#        Make        Model  ... Fuel Consumption Comb (L/100 km)  CO2 Emissions(g/km)
# 0     ACURA          ILX  ...                              8.5                  196
# 1     ACURA          ILX  ...                              9.6                  221
# 2     ACURA   ILX HYBRID  ...                              5.9                  136
# 3     ACURA      MDX 4WD  ...                             11.1                  255
# 4     ACURA      RDX AWD  ...                             10.6                  244
# ...     ...          ...  ...                              ...                  ...
# 7380  VOLVO  XC40 T5 AWD  ...                              9.4                  219
# 7381  VOLVO  XC60 T5 AWD  ...                              9.9                  232
# 7382  VOLVO  XC60 T6 AWD  ...                             10.3                  240
# 7383  VOLVO  XC90 T5 AWD  ...                              9.9                  232
# ...

# %%
# Look at the first ten items in the CO2 emissions array
cars_co2_emissions[:10]
# Out:
# array([196, 221, 136, 255, 244, 230, 232, 255, 267, 212])

# %% [markdown]
# ## 💪 Challenge I
# Help your colleague gain insights on the type of vehicles that have lower CO2 emissions. Include:
#
# 1. What is the median engine size in liters?
# 2. What is the average fuel consumption for regular gasoline (Fuel Type = X), premium gasoline (Z), ethanol (E), and diesel (D)?
# 3. What is the correlation between fuel consumption and CO2 emissions?
# 4. Which vehicle class has lower average CO2 emissions, 'SUV - SMALL' or 'MID-SIZE'?
# 5. What are the average CO2 emissions for all vehicles? For vehicles with an engine size of 2.0 liters or smaller?
# 6. Any other insights you found during your analysis?

# %%
cars.head()
# Out:
#     Make       Model  ... Fuel Consumption Comb (L/100 km)  CO2 Emissions(g/km)
# 0  ACURA         ILX  ...                              8.5                  196
# 1  ACURA         ILX  ...                              9.6                  221
# 2  ACURA  ILX HYBRID  ...                              5.9                  136
# 3  ACURA     MDX 4WD  ...                             11.1                  255
# 4  ACURA     RDX AWD  ...                             10.6                  244
#
# [5 rows x 9 columns]

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Lets explore the dataset to find out whether it is clean and also do some statistical analysis on it

# %%
# Let's begin by familiarizing ourselves with the dataset
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  8   CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 519.4+ KB

# %% [markdown]
# There are 9 columns, and out of them 5 (Make, Model, Vehicle Class, Transmission and Fuel Type) are object datatype while the rest (Engine Size(L), Cylinders, Fuel Consumption Comb (L/100 km), and CO2 Emissions(g/km)) are numeric datatype

# %%
# What is the dimention of the dataset
cars.shape
# Out:
# (7385, 9)

# %% [markdown]
# From above, the dataset is made up of 7385 row and 9 columns

# %%
# Are there null or missing values?
print(cars.isnull().sum())
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption Comb (L/100 km)    0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# There are no missing values across the dataset

# %%
# Let's get a summary from the data
cars.describe(include='all')
# Out:
#         Make  ... CO2 Emissions(g/km)
# count   7385  ...         7385.000000
# unique    42  ...                 NaN
# top     FORD  ...                 NaN
# freq     628  ...                 NaN
# mean     NaN  ...          250.584699
# std      NaN  ...           58.512679
# min      NaN  ...           96.000000
# 25%      NaN  ...          208.000000
# 50%      NaN  ...          246.000000
# 75%      NaN  ...          288.000000
# max      NaN  ...          522.000000
#
# [11 rows x 9 columns]

# %% [markdown]
# ### 1. What is the median engine size in liters?

# %%
median_engine_size = cars['Engine Size(L)'].median()
print(f'The median engine size is: { median_engine_size} liters')
# Out:
# The median engine size is: 3.0 liters

# %% [markdown]
# ### 2. What is the average fuel consumption for regular gasoline (Fuel Type = X), premium gasoline (Z), ethanol (E), and diesel (D)?

# %%
fuel_types = ['D', 'E', 'X', 'Z']
for fuel_type in fuel_types:
    avg_fuel_consumption = cars[cars['Fuel Type'] == fuel_type]['Fuel Consumption Comb (L/100 km)'].mean()
    print(f'The average fuel consumption for, {fuel_type} is {avg_fuel_consumption}, Litre/100 km.')
# Out:
# The average fuel consumption for, D is 8.835428571428572, Litre/100 km.
# The average fuel consumption for, E is 16.861351351351352, Litre/100 km.
# The average fuel consumption for, X is 10.084575199340117, Litre/100 km.
# The average fuel consumption for, Z is 11.422767020612117, Litre/100 km.

# %% [markdown]
# ### 3. What is the correlation between fuel consumption and CO2 emissions?

# %%
a = np.corrcoef(cars['Fuel Consumption Comb (L/100 km)'], cars['CO2 Emissions(g/km)'])
display(a)
display(0.9180515723870847)
# Out:
# array([[1.        , 0.91805157],
#        [0.91805157, 1.        ]])
# 0.9180515723870847

# %%
x = cars['Fuel Consumption Comb (L/100 km)'] 
y = cars['CO2 Emissions(g/km)']

plt.title('Correlation')

plt.scatter(x, y)


plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))
         (np.unique(x)), color='red')

plt.xlabel('Fuel Consumption Comb (L/100 km)')
plt.ylabel('CO2 Emissions(g/km)');

# %%
correlation = np.corrcoef(cars['Fuel Consumption Comb (L/100 km)'], cars['CO2 Emissions(g/km)'])
# cars['Fuel Consumption Comb (L/100 km)'].corr(cars['CO2 Emissions(g/km)'])
display(correlation)
print(f'The correlation between fuel consumption and CO2 emissions is 0.91805157')
# Out:
# array([[1.        , 0.91805157],
#        [0.91805157, 1.        ]])
# The correlation between fuel consumption and CO2 emissions is 0.91805157

# %% [markdown]
# From above, one can see that there is a very strong correlation between CO2 emission and fuel consumption. This means that the more the fuel consumption the more the combustion (CO2 emission)

# %% [markdown]
# ### 4. Which vehicle class has lower average CO2 emissions, 'SUV - SMALL' or 'MID-SIZE'?

# %%
co2_by_class = (cars.groupby('Vehicle Class')['CO2 Emissions(g/km)'].mean())
print(co2_by_class)
print('------------'*5)
if co2_by_class['SUV - SMALL'] < co2_by_class['MID-SIZE']:
    print(f'SUV - SMALL has lower average CO2 emissions')
else:
    print('MID-SIZE has lower average CO2 emissions')
# Out:
# Vehicle Class
# COMPACT                     216.679061
# FULL-SIZE                   263.316119
# MID-SIZE                    222.455428
# MINICOMPACT                 236.607362
# MINIVAN                     262.312500
# PICKUP TRUCK - SMALL        278.968553
# PICKUP TRUCK - STANDARD     301.513011
# SPECIAL PURPOSE VEHICLE     237.597403
# STATION WAGON - MID-SIZE    238.698113
# STATION WAGON - SMALL       200.067460
# SUBCOMPACT                  246.448845
# SUV - SMALL                 236.292523
# SUV - STANDARD              304.836735
# TWO-SEATER                  277.454348
# VAN - CARGO                 361.500000
# VAN - PASSENGER             397.212121
# Name: CO2 Emissions(g/km), dtype: float64
# ------------------------------------------------------------
# MID-SIZE has lower average CO2 emissions

# %%
a = ['COMPACT', 'TWO-SEATER', 'MINICOMPACT',
       'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
       'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
       'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
       'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL']
#b = cars['Vehicle Class'].isin(a)
b = cars[cars['Vehicle Class'].isin(a)].index
#c = cars[b]
c = cars.drop(index=b)
sns.countplot(c)
# Out:
# <AxesSubplot: ylabel='count'>

# %% [markdown]
# Mid-size vehicles have an average of 222.455428 CO2 emission, while suv-smaall average 236.292523 CO2 emission. if these figures are compared, can clearly see that suv-smaal has a higher average of CO2 emission out of the two.

# %% [markdown]
# ### 5. What are the average CO2 emissions for all vehicles? For vehicles with an engine size of 2.0 liters or smaller?

# %%
avg_co2_all = cars['CO2 Emissions(g/km)'].mean()
avg_co2_small_engine = cars[cars['Engine Size(L)'] <= 2.0]['CO2 Emissions(g/km)'].mean()
display(f'The average CO2 emissions for all vehicles is {avg_co2_all} g/km.')
display(f'The average CO2 emissions for vehicles with an engine size of 2.0 liters or smaller is, {avg_co2_small_engine} g/km.')
# Out:
# 'The average CO2 emissions for all vehicles is 250.58469871360867 g/km.'
# 'The average CO2 emissions for vehicles with an engine size of 2.0 liters or smaller is, 198.26783530370975 g/km.'

# %% [markdown]
# ## 6. Any other insights found during  analysis?

# %%
# create a scatter plot of vehicle weight vs CO2 emissions to identify any unusual patterns
plt.figure(figsize=[10,8])
plt.scatter(cars['Vehicle Class'], cars['CO2 Emissions(g/km)'])
plt.xlabel('Vehicle Weight')
plt.ylabel('CO2 Emissions(g/km)')
plt.xticks(rotation=70)
plt.show()

# %%
# group the data by cylinders, transmission, and fuel type
group = cars.groupby(['Cylinders', 'Transmission', 'Fuel Type'])

# calculate the mean CO2 emissions for each group
co2_means = group['CO2 Emissions(g/km)'].mean()

# print the mean CO2 emissions for each group
co2_means
# Out:
# Cylinders  Transmission  Fuel Type
# 3          A8            X            190.500000
#            A9            X            199.000000
#            AM5           Z            148.500000
#            AM6           Z            155.333333
#            AM7           Z            174.000000
#                                          ...
# 12         AM8           Z            370.000000
#            AS7           Z            363.294118
#            AS8           Z            381.971429
#            M7            Z            450.000000
# 16         AM7           Z            522.000000
# Name: CO2 Emissions(g/km), Length: 166, dtype: float64

# %%
# compare CO2 emissions by number of cylinders
cylinders = cars.groupby('Cylinders')['CO2 Emissions(g/km)'].mean()
display(cylinders.sort_values(ascending=False))
# Out:
# Cylinders
# 16    522.000000
# 12    381.033113
# 10    361.309524
# 8     320.619116
# 6     263.446852
# 5     235.692308
# 4     204.859938
# 3     174.894737
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# It is obvious that number of cylinder has an effect on how CO2 is emitted. The more the cylinder in a car, the more more CO2 is emitted.

# %%
# compare CO2 emissions by transmission type
transmission = cars.groupby('Transmission')['CO2 Emissions(g/km)'].mean()
display(transmission.sort_values(ascending=False).head())
# Out:
# Transmission
# A10    315.161290
# A7     312.716981
# A5     298.630952
# A4     292.953846
# A8     283.908163
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# 1. A10    315.161290<br>
# 2. A7     312.716981<br>
# 3. A5     298.630952<br>
# 4. A4     292.953846<br>
# 5. A8     283.908163<br>
# These are the top five CO2 emitters base on the type of transmission

# %%
# compare CO2 emissions by fuel type
fuel_type = cars.groupby('Fuel Type')['CO2 Emissions(g/km)'].mean()
display(fuel_type.sort_values(ascending=False))
# Out:
# Fuel Type
# E    275.091892
# Z    266.043410
# D    237.548571
# X    235.119329
# N    213.000000
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# Ethanol (E85), Premium gasoline (Z), and Diesel (D) are the top CO2 emitters base on fuel type respectively.

# %% [markdown]
# ## 💾 The data II
#
# ### You have access to the following tables:
#
# #### products
# - "product_id" - Product identifier.
# - "product_name" - The name of the bicycle.
# - "brand_id" - You can look up the brand's name in the "brands" table.
# - "category_id" - You can look up the category's name in the "categories" table.
# - "model_year" - The model year of the bicycle.
# - "list_price" - The price of the bicycle.
#
# #### brands
# - "brand_id" - Matches the identifier in the "products" table.
# - "brand_name" - One of the nine brands the store sells.
#
# #### categories
# - "category_id" - Matches the identifier in the "products" table.
# - "category_name" - One of the seven product categories in the store.

# %% [markdown]
# ## A note on SQL
# You can click the "Browse tables" button in the upper right-hand corner of the SQL cell below to view the available tables. They will show on the left of the notebook.
#
# It is also important to note that the database used in this challenge is a slightly different version (SQL Server) from the one used in the Introduction to SQL course (PostgreSQL). You might notice that the keyword **LIMIT** does not exist in SQL Server.

# %%
SELECT * 
FROM products;
# Out:
#      product_id                          product_name  ...  model_year  list_price
# 0             1                       Trek 820 - 2016  ...        2016      379.99
# 1             2    Ritchey Timberwolf Frameset - 2016  ...        2016      749.99
# 2             3       Surly Wednesday Frameset - 2016  ...        2016      999.99
# 3             4              Trek Fuel EX 8 29 - 2016  ...        2016     2899.99
# 4             5          Heller Shagamaw Frame - 2016  ...        2016     1320.99
# ..          ...                                   ...  ...         ...         ...
# 316         317          Trek Checkpoint ALR 5 - 2019  ...        2019     1999.99
# 317         318  Trek Checkpoint ALR 5 Women's - 2019  ...        2019     1999.99
# 318         319   Trek Checkpoint SL 5 Women's - 2019  ...        2019     2799.99
# 319         320           Trek Checkpoint SL 6 - 2019  ...        2019     3799.99
# ...

# %%
SELECT * FROM brands;
# Out:
#    brand_id    brand_name
# 0         1       Electra
# 1         2          Haro
# 2         3        Heller
# 3         4   Pure Cycles
# 4         5       Ritchey
# 5         6       Strider
# 6         7  Sun Bicycles
# 7         8         Surly
# 8         9          Trek

# %%
SELECT * FROM categories
# Out:
#    category_id        category_name
# 0            1    Children Bicycles
# 1            2     Comfort Bicycles
# 2            3    Cruisers Bicycles
# 3            4  Cyclocross Bicycles
# 4            5       Electric Bikes
# 5            6       Mountain Bikes
# 6            7           Road Bikes

# %% [markdown]
# ## 💪 Challenge II
# Help your team leader understand your company's products. Include:
#
# 1. What is the most expensive item your company sells? The least expensive?
# 2. How many different products of each category does your company sell?
# 3. What are the top three brands with the highest average list price? The top three categories?
# 4. Any other insights you found during your analysis?

# %% [markdown]
# ### 1. What is the most expensive item your company sells?

# %%
SELECT product_name, list_price
FROM products
WHERE list_price = (SELECT MAX(list_price) FROM products);
# Out:
#                     product_name  list_price
# 0  Trek Domane SLR 9 Disc - 2018    11999.99

# %% [markdown]
# Trek Domane SLR 9 Disc- 2018 is the most expensive item sold buy the company with a price tag of $11999.99

# %% [markdown]
# ### 1b. The least expensive?

# %%
SELECT product_name, list_price
FROM products
WHERE list_price = (SELECT MIN(list_price) FROM products);
# Out:
#                              product_name  list_price
# 0  Strider Classic 12 Balance Bike - 2018       89.99

# %% [markdown]
# The least expensive item soldby thr company is Strider Classic 12 Balance Bike - 2018, with price of $89.99

# %% [markdown]
# ### 2. How many different products of each category does your company sell?

# %%
SELECT distinct(category_name), COUNT(*) AS num_products
FROM products
JOIN categories
ON products.category_id = categories.category_id
GROUP BY products.category_id, categories.category_name;
# Out:
#          category_name  num_products
# 0    Children Bicycles            59
# 1     Comfort Bicycles            30
# 2    Cruisers Bicycles            78
# 3  Cyclocross Bicycles            10
# 4       Electric Bikes            24
# 5       Mountain Bikes            60
# 6           Road Bikes            60

# %% [markdown]
# The company sell's 59 different products for children bicycles category, 30 in comfort bicycles, 78 cruiser bicycles, 10 cyclocross bicycles, 24 of electric bikes, 60 for both moutain and road bike.

# %% [markdown]
# ### 3. What are the top three brands with the highest average list price? The top three categories?

# %%
SELECT TOP 3 brand_name, AVG(list_price) AS avg_price
FROM products
JOIN brands
ON products.brand_id = brands.brand_id
GROUP BY products.brand_id, brands.brand_name
ORDER BY avg_price DESC;
# Out:
#   brand_name    avg_price
# 0       Trek  2500.064074
# 1     Heller  2172.996666
# 2      Surly  1331.753600

# %% [markdown]
# The top three brands with the highest list price are Trek ($2500.06), Heller($2172.99), and Surly ($1331.75
# ) respectively.

# %% [markdown]
# ### Other insights

# %% [markdown]
# ### What is the distribution of products across categories? (Are there any categories with significantly fewer or more products than others?)

# %%
SELECT categories.category_name, COUNT(products.product_id) AS num_products, 
ROUND(COUNT(products.product_id)*100.0/SUM(COUNT(products.product_id)) OVER(),2) AS percentage_of_products
FROM products
JOIN categories
ON products.category_id = categories.category_id
GROUP BY categories.category_name
ORDER BY num_products DESC;
# Out:
#          category_name  num_products  percentage_of_products
# 0    Cruisers Bicycles            78                   24.30
# 1       Mountain Bikes            60                   18.69
# 2           Road Bikes            60                   18.69
# 3    Children Bicycles            59                   18.38
# 4     Comfort Bicycles            30                    9.35
# 5       Electric Bikes            24                    7.48
# 6  Cyclocross Bicycles            10                    3.12

# %% [markdown]
# Cyclocross Bicycles, Electric Bikes and Comfort Bicycles are  categories with few products

# %% [markdown]
# ### Are there any brands or categories with significantly higher or lower prices than others?

# %%
SELECT brands.brand_name, categories.category_name, AVG(products.list_price) AS avg_price
FROM products
JOIN brands
ON products.brand_id = brands.brand_id
JOIN categories
ON products.category_id = categories.category_id
GROUP BY brands.brand_name, categories.category_name
ORDER BY avg_price DESC;
# Out:
#       brand_name        category_name    avg_price
# 0           Trek       Electric Bikes  3511.101111
# 1           Trek           Road Bikes  3430.178679
# 2           Trek  Cyclocross Bicycles  3183.323333
# 3        Electra       Electric Bikes  2799.990000
# 4         Heller       Mountain Bikes  2172.996666
# 5           Trek       Mountain Bikes  1926.275714
# 6          Surly  Cyclocross Bicycles  1581.997500
# 7   Sun Bicycles       Electric Bikes  1559.990000
# 8          Surly       Mountain Bikes  1303.134285
# 9          Surly           Road Bikes  1245.995714
# 10          Haro       Mountain Bikes   869.990000
# 11  Sun Bicycles       Mountain Bikes   832.990000
# 12       Electra    Cruisers Bicycles   786.394843
# 13       Electra     Comfort Bicycles   772.370952
# 14       Ritchey       Mountain Bikes   749.990000
# 15  Sun Bicycles    Cruisers Bicycles   483.262727
# 16  Sun Bicycles     Comfort Bicycles   471.545555
# ...

# %% [markdown]
# Trek and electra are the brand with significantly higher price base on brand and category while children bicycle is the category with significantly lower price.

# %% [markdown]
# ### Average list price for product categories

# %%
SELECT category_name, AVG(list_price) AS avg_price
FROM products
JOIN categories
ON products.category_id = categories.category_id
GROUP BY products.category_id, categories.category_name
ORDER BY avg_price DESC
# Out:
#          category_name    avg_price
# 0       Electric Bikes  3281.656666
# 1           Road Bikes  3175.357333
# 2  Cyclocross Bicycles  2542.793000
# 3       Mountain Bikes  1649.757333
# 4    Cruisers Bicycles   730.412307
# 5     Comfort Bicycles   682.123333
# 6    Children Bicycles   287.786610

# %% [markdown]
# The list of product categories ranks electric bikes as the most expensive, followed by road bikes, and finally cyclocross bikes, with their average prices shown above.

# %% [markdown]
# ## ⌛️ Time is ticking. Good luck!
